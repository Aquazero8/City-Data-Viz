# %%
from google.colab import files
uploaded = files.upload() # upload SocialNetwork.csv file
# Out:
#      <input type="file" id="files-dce0bf5b-6842-46f4-b127-f8c5166619e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dce0bf5b-6842-46f4-b127-f8c5166619e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd
import numpy as np

socialNetworkData = pd.read_csv(io.BytesIO(uploaded['SocialNetwork.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
socialNetworkData
# Out:
#                     timestamp  participantIdFrom  participantIdTo
# 0        2022-03-01T00:00:00Z                173              180
# 1        2022-03-01T00:00:00Z                178              183
# 2        2022-03-01T00:00:00Z                178              185
# 3        2022-03-01T00:00:00Z                180              173
# 4        2022-03-01T00:00:00Z                183              178
# ...                       ...                ...              ...
# 7482483  2023-05-25T00:00:00Z                879              102
# 7482484  2023-05-25T00:00:00Z                879              851
# 7482485  2023-05-25T00:00:00Z                879              412
# 7482486  2023-05-25T00:00:00Z                879               17
# 7482487  2023-05-25T00:00:00Z                879              590
#
# [7482488 rows x 3 columns]

# %%
type(socialNetworkData)
# Out:
# pandas.core.frame.DataFrame

# %%
# Sort the result by participantIdFrom and the count of occurrences in descending order
top_connections = connections_count.sort_values(['participantIdFrom', 'count'], ascending=[True, False])

top_connections
# Out:
#         participantIdFrom  participantIdTo  count
# 23                      0              608     59
# 11                      0              367     45
# 8                       0              316     34
# 13                      0              410     34
# 48                      0              933     34
# ...                   ...              ...    ...
# 160876               1010              388      6
# 160940               1010              705      6
# 160943               1010              737      6
# 160952               1010              829      6
# 160956               1010              873      6
#
# [160966 rows x 3 columns]

# %%
# Get the unique number of connections for each participantIdFrom
unique_connections = socialNetworkData.groupby('participantIdFrom')['participantIdTo'].nunique()
unique_connections
# Out:
# participantIdFrom
# 0        55
# 1       258
# 2       211
# 3       149
# 4       261
#        ...
# 1006    277
# 1007    248
# 1008     63
# 1009    279
# 1010    154
# Name: participantIdTo, Length: 963, dtype: int64

# %%
# Combine the two results into a single dataframe
result_df = pd.merge(unique_connections, top_10_connections, on='participantIdFrom')

result_df
# Out:
#       participantIdFrom  participantIdTo_x  participantIdTo_y  count
# 0                     0                 55                608     59
# 1                     0                 55                367     45
# 2                     0                 55                316     34
# 3                     0                 55                410     34
# 4                     0                 55                933     34
# ...                 ...                ...                ...    ...
# 8621               1010                154                540     81
# 8622               1010                154                283     77
# 8623               1010                154                438     77
# 8624               1010                154                252     74
# 8625               1010                154                305     70
#
# [8626 rows x 4 columns]

# %%
# save the results to a new CSV file
result_df.to_csv('result_df.csv', index=False)
files.download('result_df.csv')
